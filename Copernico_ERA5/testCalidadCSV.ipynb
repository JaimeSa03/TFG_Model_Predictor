# %% [markdown]
# # Esto es un script para ver si el csv está bien creado.

# %% [markdown]
#  1. Estructura: # Columnas correctas, tipos de datos
#  2. Temporal # Que tienes las 8.784h de 2020 sin huecos
#  3. Nulos # Que la limpieza funcionó bien
#  4. Rangos físicos # Que la temperatura no es -500K ni el viento 900 m/s
#  5. Geografía # Que todos los puntos están en España
#  6. Visualizaciones # Que los patrones estacionales tienen sentido
#  7. Estadísticas # Resumen numérico completo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os

from files.validacion import ES_BISIESTO

# ============================================================
# CONFIGURACIÓN GENERAL
# ============================================================
YEARS     = range(2020, 2025) 
# YEARS     = range(2025, 2026)
BASE_PATH = "."


# Umbrales térmicos - deben coincidir con pipeline.py
T_REF_FRIO  = 19.0  # °C — por debajo activa calefacción 
T_REF_CALOR = 27.0  # °C — por encima activa refrigeración

# ============================================================
# COLUMNAS ESPERADAS EN EL CSV
# ============================================================
COLUMNAS_ESPERADAS = [
    'time',
    # Demanda térmica - 46 capitales colapsadas en 3 columnas
    'hdd_peninsular_ponderado',     # estrés por frío (pesos INE dinámicos)
    'cdd_peninsular_ponderado',     # estrés por calor (pesos INE dinámicos)
    'estres_termico_total',         # HDD + CDD (U-shape resuelta)
    # Solar - ponderado por potencia instalada del año
    'ssrd_solar_ponderado',         # radiación solar (J/m²)
    'tcc_solar_ponderado',          # nubosidad (0-1)
    't2m_celsius_solar_ponderado',  # temperatura solar (°C)
    # Eólica - ponderado por potencia instalada del año
    'wind_speed_100m_ponderado',    # velocidad viento 100m (m/s)
    'wind_speed_10m_ponderado',     # velocidad viento 10m (m/s)
    'wind_shear_ponderado',         # gradiente vertical (ratio, capeado a 5)
    'densidad_aire_eolica',          # densidad del aire (kg/m³)
    'wind_power_density_ponderado',  # potencia eólica (W/m²)
    # Hidráulica - ponderado por potencia instalada (fija)
    'tp_hidro_ponderado',           # precipitación acumulada (m/h)
]

# ============================================================
# RANGOS FÍSICOS ESPERADOS PARA ESPAÑA
# Rangos para HDD/CDD horarios (escala /24)
# ============================================================
RANGOS = {
    # HDD/CDD - escala horaria (°día/h = °día / 24)
    'hdd_peninsular_ponderado': (
        0, T_REF_FRIO / 24, "°día/h",
        "HDD peninsular ponderado"
    ),
    'cdd_peninsular_ponderado': (
        0, T_REF_CALOR / 24, "°día/h",
        "CDD peninsular ponderado"
    ),
    'estres_termico_total': (
        0, (T_REF_FRIO + T_REF_CALOR) / 24, "°día/h",
        "Estrés térmico total"
    ),

    # Solar
    'ssrd_solar_ponderado':        (0,   4e6,  "J/m²", "Radiación solar ponderada"),
    'tcc_solar_ponderado':         (0,   1,    "-",    "Nubosidad ponderada"),
    't2m_celsius_solar_ponderado': (-15, 48,   "°C",   "Temperatura solar ponderada"),

    # Eólica
    'wind_speed_100m_ponderado':   (0,   60,   "m/s",  "Viento 100m ponderado"),
    'wind_speed_10m_ponderado':    (0,   40,   "m/s",  "Viento 10m ponderado"),
    'wind_shear_ponderado':        (0,   5,    "-",    "Wind shear ponderado"),       
    'densidad_aire_eolica':        (1.05, 1.40, "kg/m³",  "Densidad del aire en zonas eólicas peninsulares"),
    # Densidad del aire en España:
            # Mínima: verano en zonas altas (Sierra Nevada ~1.000 hPa, 35°C)
            #   ρ = 100000 / (287.05 × 308) = 1.131 kg/m³
            # Máxima: invierno en costa (1.020 hPa, -5°C = 268K)
            #   ρ = 102000 / (287.05 × 268) = 1.326 kg/m³
    'wind_power_density_ponderado': (0, 6000, "W/m²","Potencia eólica específica corregida por densidad"),
    # Wind Power Density:
        # Mínimo: calma total → 0
        # Máximo: ρ=1.35 kg/m³, v=20 m/s (antes del cut-out)
        #   P = 0.5 × 1.35 × 20³ = 5.400 W/m²
        # Pero siendo PONDERADO el promedio nacional raramente
        # supera 3.000 W/m² → usamos 6.000 con margen

    # Hidráulica
    'tp_hidro_ponderado':          (0,   0.15, "m",    "Precipitación hidráulica ponderada"),
}

def procesar_año(year):

    ES_BISIESTO     = (year % 4 == 0)
    HORAS_ESPERADAS = 366 * 24 if ES_BISIESTO else 365 * 24

    # ============================================================
    # CARGA
    # ============================================================
    carpeta = os.path.join(BASE_PATH, str(year))
    print(f"\n{'='*60}")
    print(f"Validación año {year}")
    print(f"{'='*60}")

    path = os.path.join(carpeta, f"dataset_{year}.csv.gz")
    if not os.path.exists(path):
        print(f"  ❌ No encontrado: {path}")
        return None
    
    df = pd.read_csv(path, compression='gzip')
    df['time'] = pd.to_datetime(df['time'])
    print(f"✅ Dataset cargado - Shape: {df.shape}")

    # ============================================================
    # BLOQUE 1 - ESTRUCTURA
    # ============================================================
    print(f"\n{'='*50}")
    print(f"📋 BLOQUE 1 - ESTRUCTURA")
    print(f"{'='*50}")

    print(f"\n🔢 Filas:    {df.shape[0]:,}")
    print(f"🔢 Columnas: {df.shape[1]}")
    print(f"\n📌 Columnas presentes:\n{df.columns.tolist()}")
    print(f"\n📌 Tipos de datos:\n{df.dtypes}")

    faltantes = [c for c in COLUMNAS_ESPERADAS if c not in df.columns]
    extras    = [c for c in df.columns if c not in COLUMNAS_ESPERADAS]

    if faltantes:
        print(f"\n⚠️  Columnas FALTANTES: {faltantes}")
    else:
        print(f"\n✅ Todas las columnas esperadas presentes")
    if extras:
        print(f"ℹ️ Columnas extra (no esperadas): {extras}")
        
    # ============================================================
    # BLOQUE 2 - COBERTURA TEMPORAL
    # ============================================================
    print(f"\n{'='*50}")
    print(f"🕐 BLOQUE 2 - COBERTURA TEMPORAL")
    print(f"{'='*50}")

    print(f"\n📅 Inicio:  {df['time'].min()}")
    print(f"📅 Fin:     {df['time'].max()}")
    print(f"📅 Horas:   {df['time'].nunique():,} / {HORAS_ESPERADAS:,} esperadas")

    if df['time'].nunique() == HORAS_ESPERADAS:
        print("✅ Cobertura temporal completa")
    else:
        diff = HORAS_ESPERADAS - df['time'].nunique()
        print(f"⚠️  Faltan {diff} horas")
        todas  = pd.date_range(f'{year}-01-01', f'{year}-12-31 23:00', freq='h')
        huecos = todas.difference(df['time'])
        if len(huecos):
            print(f"   Primeros huecos: {huecos[:5].tolist()}")

    # Verificar continuidad - no debe haber saltos > 1h
    df_s   = df.sort_values('time')
    diffs  = df_s['time'].diff().dropna()
    saltos = diffs[diffs != pd.Timedelta('1h')]
    if saltos.empty:
        print("✅ Serie temporal continua, sin saltos")
    else:
        print(f"⚠️  {len(saltos)} saltos detectados")
        print(f"   Primeros: {saltos.head(3)}")

    # ============================================================
    # BLOQUE 3 - NULOS Y DUPLICADOS
    # ============================================================
    print(f"\n{'='*50}")
    print(f"🔍 BLOQUE 3 - NULOS Y DUPLICADOS")
    print(f"{'='*50}")

    nulos     = df.isnull().sum()
    nulos_pct = (nulos / len(df) * 100).round(2)
    tabla_nulos = pd.DataFrame({'nulos': nulos, '%': nulos_pct})
    tabla_nulos = tabla_nulos[tabla_nulos['nulos'] > 0]

    if tabla_nulos.empty:
        print("\n✅ Sin valores nulos")
    else:
        print(f"\n⚠️  Columnas con nulos:\n{tabla_nulos}")

    dups = df.duplicated(subset=['time']).sum()
    print(f"\n{'✅' if dups == 0 else '⚠️'} Filas duplicadas por time: {dups}")

    # ============================================================
    # BLOQUE 4 - RANGOS FÍSICOS
    # ============================================================
    print(f"\n{'='*50}")
    print(f"🌡️  BLOQUE 4 - RANGOS FÍSICOS")
    print(f"{'='*50}")

    for col, (vmin, vmax, unidad, nombre) in RANGOS.items():
        if col not in df.columns:
            print(f"\n  ⚠️  {nombre} ({col}) - columna no encontrada")
            continue
        rmin = df[col].min()
        rmax = df[col].max()
        ok   = rmin >= vmin and rmax <= vmax
        print(f"\n  {'✅' if ok else '⚠️ '} {nombre}")
        print(f"     Esperado: [{vmin}, {vmax}] {unidad}")
        print(f"     Real:     [{rmin:.4f}, {rmax:.4f}] {unidad}")

    if 'wind_shear_ponderado' in df.columns:
        horas_capeadas = (df['wind_shear_ponderado'] == 5.0).sum()
        pct_capeadas   = horas_capeadas / len(df) * 100
        print(f"\n  ℹ️  Horas con wind_shear capeado a 5: "
            f"{horas_capeadas:,} ({pct_capeadas:.2f}%)")

        if pct_capeadas > 5:
            print(f"  ⚠️  Más del 5% de horas capeadas — "
                f"considera subir el límite a 7 o 10")
        elif pct_capeadas > 0:
            print(f"  ✅ Capeado puntual — normal en calmas "
                f"nocturnas de superficie")
            
    # ============================================================
    # BLOQUE 5 - VISUALIZACIONES
    # Panel adaptado a las nuevas columnas HDD/CDD
    # ============================================================
    print(f"\n{'='*50}")
    print(f"📊 BLOQUE 5 - VISUALIZACIONES")
    print(f"{'='*50}")

    fig = plt.figure(figsize=(20, 20))
    fig.suptitle(f'Validación Dataset ERA5 - España {year}',
                fontsize=14, fontweight='bold')
    gs = gridspec.GridSpec(4, 3, figure=fig)

    # -- Fila 1: HDD y CDD diarios ------------------------------

    # HDD peninsular ponderado - acumulado diario
    ax1 = fig.add_subplot(gs[0, :2])
    if 'hdd_peninsular_ponderado' in df.columns:
        hdd_d = df.groupby(df['time'].dt.date)['hdd_peninsular_ponderado'].sum()
        ax1.fill_between(hdd_d.index, hdd_d.values, color='steelblue', alpha=0.6)
        ax1.plot(hdd_d.index, hdd_d.values, color='steelblue', linewidth=0.6)
    ax1.set_title('HDD peninsular ponderado diario\n'
                f'(pesos INE {year} - estrés por frío, acumulado horario)')
    ax1.set_ylabel('°día acum.')
    ax1.grid(alpha=0.3)

    # CDD mensual
    ax2 = fig.add_subplot(gs[0, 2])
    if 'cdd_peninsular_ponderado' in df.columns:
        cdd_m = df.groupby(df['time'].dt.month)['cdd_peninsular_ponderado'].sum()
        ax2.bar(cdd_m.index, cdd_m.values, color='tomato')
    ax2.set_title('CDD mensual\n(estrés por calor)')
    ax2.set_xlabel('Mes')
    ax2.grid(alpha=0.3, axis='y')

    # -- Fila 2: Estrés térmico total y scatter HDD vs CDD ------

    # Estrés térmico total diario - U-shape resuelta
    ax3 = fig.add_subplot(gs[1, :2])
    if 'estres_termico_total' in df.columns:
        et_d = df.groupby(df['time'].dt.date)['estres_termico_total'].sum()
        ax3.plot(et_d.index, et_d.values, color='purple', linewidth=0.7)
        ax3.fill_between(et_d.index, et_d.values, color='purple', alpha=0.15)
    ax3.set_title('Estrés térmico total diario (HDD + CDD)\n'
                'El modelo ve la U-shape completa en una sola variable')
    ax3.set_ylabel('°día acum.')
    ax3.grid(alpha=0.3)

    # [TODO] HDD vs CDD scatter
    # ¿Si un punto tiene HDD alto, CDD debe ser 0 y viceversa?
    ax4 = fig.add_subplot(gs[1, 2])
    if 'hdd_peninsular_ponderado' in df.columns and \
    'cdd_peninsular_ponderado' in df.columns:
        # Muestrear para no sobrecargar el scatter
        df_sample = df.sample(min(2000, len(df)), random_state=42)
        ax4.scatter(df_sample['hdd_peninsular_ponderado'],
                    df_sample['cdd_peninsular_ponderado'],
                    alpha=0.2, s=2, color='purple')
    ax4.set_xlabel('HDD (frío)')
    ax4.set_ylabel('CDD (calor)')
    ax4.set_title('HDD vs CDD\n')
    ax4.grid(alpha=0.3)

    # -- Fila 3: Solar y viento ----------------------------------

    # Radiación solar ponderada diaria
    ax5 = fig.add_subplot(gs[2, :2])
    if 'ssrd_solar_ponderado' in df.columns:
        rad_d = df.groupby(df['time'].dt.date)['ssrd_solar_ponderado'].mean() / 1e6
        ax5.plot(rad_d.index, rad_d.values, color='goldenrod', linewidth=0.7)
        ax5.fill_between(rad_d.index, rad_d.values, color='goldenrod', alpha=0.2)
    ax5.set_title('Radiación solar media diaria ponderada (MJ/m²)\n'
                'Esperado: campana con máximo en junio/julio')
    ax5.set_ylabel('MJ/m²')
    ax5.grid(alpha=0.3)

    # Viento 100m ponderado diario
    ax6 = fig.add_subplot(gs[2, 2])
    if 'wind_speed_100m_ponderado' in df.columns:
        v_d = df.groupby(df['time'].dt.date)['wind_speed_100m_ponderado'].mean()
        ax6.plot(v_d.index, v_d.values, color='seagreen', linewidth=0.7)
    ax6.set_title('Viento 100m\nponderado (m/s)')
    ax6.grid(alpha=0.3)

    # -- Fila 4: Precipitación + correlación ---------------------

    # Precipitación hidráulica mensual
    ax7 = fig.add_subplot(gs[3, 0])
    if 'tp_hidro_ponderado' in df.columns:
        tp_m = df.groupby(df['time'].dt.month)['tp_hidro_ponderado'].sum() * 1000
        ax7.bar(tp_m.index, tp_m.values, color='steelblue')
    ax7.set_title('Precipitación mensual\nhidráulica ponderada (mm)')
    ax7.set_xlabel('Mes')
    ax7.grid(alpha=0.3, axis='y')

    # Temperatura solar ponderada diaria
    ax8 = fig.add_subplot(gs[3, 1])
    if 't2m_celsius_solar_ponderado' in df.columns:
        t_d = df.groupby(df['time'].dt.date)['t2m_celsius_solar_ponderado'].mean()
        ax8.plot(t_d.index, t_d.values, color='tomato', linewidth=0.7)
        ax8.axhline(y=T_REF_FRIO,  color='steelblue', linestyle='--',
                    alpha=0.5, label=f'{T_REF_FRIO}°C HDD ref')
        ax8.axhline(y=T_REF_CALOR, color='tomato',    linestyle='--',
                    alpha=0.5, label=f'{T_REF_CALOR}°C CDD ref')
        ax8.legend(fontsize=7)
    ax8.set_title('Temperatura solar ponderada\ndiaria (°C)')
    ax8.set_ylabel('°C')
    ax8.grid(alpha=0.3)

    # Matriz de correlación - variables clave del modelo
    ax9 = fig.add_subplot(gs[3, 2])
    cols_corr = [c for c in [
        'hdd_peninsular_ponderado',
        'cdd_peninsular_ponderado',
        'estres_termico_total',
        'ssrd_solar_ponderado',
        'tcc_solar_ponderado',
        'wind_speed_100m_ponderado',
        'wind_shear_ponderado',
        'tp_hidro_ponderado',
    ] if c in df.columns]

    if cols_corr:
        corr = df[cols_corr].corr()
        im   = ax9.imshow(corr, cmap='RdBu_r', vmin=-1, vmax=1)
        lbls = [c.replace('_peninsular_ponderado', '')
                .replace('_ponderado', '')
                .replace('wind_speed_', 'v')
                .replace('t2m_celsius_', 't_')
                for c in cols_corr]
        ax9.set_xticks(range(len(cols_corr)))
        ax9.set_yticks(range(len(cols_corr)))
        ax9.set_xticklabels(lbls, rotation=45, ha='right', fontsize=6)
        ax9.set_yticklabels(lbls, fontsize=6)
        ax9.set_title('Correlación\nvariables clave')
        plt.colorbar(im, ax=ax9)

    plt.tight_layout()
    output_img = f"{year}/validacion_{year}.png"
    plt.savefig(output_img, dpi=150, bbox_inches='tight')
    plt.show()
    print(f"  ✅ Gráfico guardado: {output_img}")

    # ============================================================
    # BLOQUE 6 - RESUMEN ESTADÍSTICO
    # ============================================================
    print(f"\n{'='*50}")
    print(f"📊 BLOQUE 6 - RESUMEN ESTADÍSTICO")
    print(f"{'='*50}")

    # Resumen térmico
    print(f"\n🌡️  TÉRMICO (pesos INE {year}):")
    cols_t = ['hdd_peninsular_ponderado',
            'cdd_peninsular_ponderado',
            'estres_termico_total']
    cols_t = [c for c in cols_t if c in df.columns]
    if cols_t:
        print(df[cols_t].describe().round(6).to_string())

        # -- Análisis de solapamiento HDD/CDD ---------------------
        # El solapamiento NO es un error - es física real de España:
        # mientras Soria tiene calefacción, Sevilla tiene A/C.
        # Ocurre en horas de transición (primavera, otoño, madrugadas)
        # donde el gradiente térmico norte/sur es máximo.

        if all(c in df.columns for c in
            ['hdd_peninsular_ponderado', 'cdd_peninsular_ponderado']):

            mascara_solapamiento = (
                (df['hdd_peninsular_ponderado'] > 0) &
                (df['cdd_peninsular_ponderado'] > 0)
            )
            horas_solapamiento = mascara_solapamiento.sum()

            print(f"\n  ℹ️  Horas con HDD>0 y CDD>0 simultáneamente: "
                f"{horas_solapamiento:,} "
                f"({horas_solapamiento/len(df)*100:.1f}% del año)")
            print(f"  ✅ Esto es física real - norte frío + sur cálido a la vez")
            print(f"     El modelo aprende este gradiente térmico peninsular")

            # Distribución mensual del solapamiento
            # ¿En qué meses coexisten calefacción (norte) y A/C (sur)?
            df_solap = df[mascara_solapamiento].copy()
            if not df_solap.empty:
                por_mes = df_solap.groupby(
                    df_solap['time'].dt.month
                ).size()

                nombres_mes = {
                    1:'Ene', 2:'Feb', 3:'Mar', 4:'Abr',
                    5:'May', 6:'Jun', 7:'Jul', 8:'Ago',
                    9:'Sep', 10:'Oct', 11:'Nov', 12:'Dic'
                }

                print(f"\n  📅 Distribución mensual del solapamiento "
                    f"(norte frío + sur cálido simultáneo):")
                print(f"  {'Mes':<6} {'Horas':>6} {'% del mes':>10} "
                    f"{'Barra visual'}")
                print(f"  {'-'*55}")

                for mes, horas in por_mes.items():
                    # Horas totales del mes para calcular porcentaje
                    horas_mes = (
                        df['time'].dt.month == mes
                    ).sum()
                    pct = horas / horas_mes * 100
                    barra = '█' * int(pct / 2)
                    print(f"  {nombres_mes[mes]:<6} {horas:>6,} "
                        f"{pct:>9.1f}%  {barra}")

                # Meses con más solapamiento - corroboran la hipótesis
                mes_max = por_mes.idxmax()
                mes_min = por_mes[por_mes > 0].idxmin() \
                        if (por_mes > 0).any() else None

                print(f"\n  🔝 Mes con más solapamiento:   "
                    f"{nombres_mes[mes_max]} "
                    f"({por_mes[mes_max]:,}h) "
                    f"← transición térmica máxima")
                if mes_min:
                    print(f"  🔽 Mes con menos solapamiento: "
                        f"{nombres_mes[mes_min]} "
                        f"({por_mes[mes_min]:,}h) "
                        f"← clima más homogéneo")

                # Verificar hipótesis: ¿el solapamiento es mayor en
                # meses de transición (mar,abr,may,sep,oct,nov)?
                meses_transicion = [3, 4, 5, 9, 10, 11]
                meses_extremo    = [1, 2, 6, 7, 8, 12]

                h_transicion = por_mes[
                    por_mes.index.isin(meses_transicion)
                ].sum()
                h_extremo = por_mes[
                    por_mes.index.isin(meses_extremo)
                ].sum()

                print(f"\n  📊 Verificación hipótesis climática:")
                print(f"     Meses de transición "
                    f"(Mar-May, Sep-Nov): {h_transicion:,}h "
                    f"({h_transicion/horas_solapamiento*100:.1f}%)")
                print(f"     Meses extremos "
                    f"(Ene-Feb, Jun-Ago, Dic): {h_extremo:,}h "
                    f"({h_extremo/horas_solapamiento*100:.1f}%)")

                if h_transicion > h_extremo:
                    print(f"     ✅ Confirmado: el solapamiento es mayor "
                        f"en meses de transición")
                else:
                    print(f"     ℹ️  El solapamiento se distribuye de "
                        f"forma atípica - año {year} inusual")

                # Análisis por hora del día - ¿a qué hora ocurre más?
                por_hora = df_solap.groupby(
                    df_solap['time'].dt.hour
                ).size()

                hora_pico = por_hora.idxmax()
                print(f"\n  🕐 Hora del día con más solapamiento: "
                    f"{hora_pico:02d}:00h "
                    f"({por_hora[hora_pico]:,} ocurrencias)")
                print(f"     {'Madrugada (0-6h)' if hora_pico < 6 else 'Mañana (6-12h)' if hora_pico < 12 else 'Tarde (12-18h)' if hora_pico < 18 else 'Noche (18-24h)'}"
                    f" - cuando el gradiente N/S es más pronunciado")

    # Resumen energético
    print("\n⚡ ENERGÉTICO:")
    cols_e = ['ssrd_solar_ponderado', 'tcc_solar_ponderado',
            't2m_celsius_solar_ponderado',
            'wind_speed_100m_ponderado', 'wind_speed_10m_ponderado',
            'wind_shear_ponderado', 'tp_hidro_ponderado']
    cols_e = [c for c in cols_e if c in df.columns]
    if cols_e:
        print(df[cols_e].describe().round(4).to_string())

    print(f"\n{'='*60}")
    print(f"\n✅ Validación {year} completada")
    print("="*60)
    
# ============================================================
# EJECUCIÓN
# ============================================================
if __name__ == "__main__":

    for year in YEARS:
        shape = procesar_año(year)
# Out:
# ============================================================
# Validación año 2020
# ============================================================
# ✅ Dataset cargado - Shape: (8784, 13)
#
# ==================================================
# 📋 BLOQUE 1 - ESTRUCTURA
# ==================================================
#
# 🔢 Filas:    8,784
# 🔢 Columnas: 13
#
# 📌 Columnas presentes:
# ['time', 'tcc_solar_ponderado', 'hdd_peninsular_ponderado', 'cdd_peninsular_ponderado', 'estres_termico_total', 'ssrd_solar_ponderado', 'tp_hidro_ponderado', 'wind_speed_100m_ponderado', 'wind_speed_10m_ponderado', 'wind_shear_ponderado', 'densidad_aire_eolica', 'wind_power_density_ponderado', 't2m_celsius_solar_ponderado']
#
# 📌 Tipos de datos:
# time                            datetime64[us]
# tcc_solar_ponderado                    float64
# hdd_peninsular_ponderado               float64
# cdd_peninsular_ponderado               float64
# estres_termico_total                   float64
# ssrd_solar_ponderado                   float64
# tp_hidro_ponderado                     float64
# wind_speed_100m_ponderado              float64
# wind_speed_10m_ponderado               float64
# wind_shear_ponderado                   float64
# densidad_aire_eolica                   float64
# wind_power_density_ponderado           float64
# t2m_celsius_solar_ponderado            float64
# dtype: object
#
# ✅ Todas las columnas esperadas presentes
#
# ==================================================
# 🕐 BLOQUE 2 - COBERTURA TEMPORAL
# ==================================================
#
# 📅 Inicio:  2020-01-01 00:00:00
# 📅 Fin:     2020-12-31 23:00:00
# 📅 Horas:   8,784 / 8,784 esperadas
# ✅ Cobertura temporal completa
# ✅ Serie temporal continua, sin saltos
#
# ==================================================
# 🔍 BLOQUE 3 - NULOS Y DUPLICADOS
# ==================================================
#
# ✅ Sin valores nulos
#
# ✅ Filas duplicadas por time: 0
#
# ==================================================
# 🌡️  BLOQUE 4 - RANGOS FÍSICOS
# ==================================================
#
#   ✅ HDD peninsular ponderado
#      Esperado: [0, 0.7916666666666666] °día/h
#      Real:     [0.0000, 0.7656] °día/h
#
#   ✅ CDD peninsular ponderado
#      Esperado: [0, 1.125] °día/h
#      Real:     [0.0000, 0.2750] °día/h
#
#   ✅ Estrés térmico total
#      Esperado: [0, 1.9166666666666667] °día/h
#      Real:     [0.0000, 0.7656] °día/h
#
#   ✅ Radiación solar ponderada
#      Esperado: [0, 4000000.0] J/m²
#      Real:     [0.0000, 3513152.2000] J/m²
#
#   ✅ Nubosidad ponderada
#      Esperado: [0, 1] -
#      Real:     [0.0010, 0.9978] -
#
#   ✅ Temperatura solar ponderada
#      Esperado: [-15, 48] °C
#      Real:     [0.5255, 34.8787] °C
#
#   ✅ Viento 100m ponderado
#      Esperado: [0, 60] m/s
#      Real:     [0.0257, 12.0941] m/s
#
#   ✅ Viento 10m ponderado
#      Esperado: [0, 40] m/s
#      Real:     [0.0363, 8.7364] m/s
#
#   ✅ Wind shear ponderado
#      Esperado: [0, 5] -
#      Real:     [0.1710, 5.0000] -
#
#   ✅ Densidad del aire en zonas eólicas peninsulares
#      Esperado: [1.05, 1.4] kg/m³
#      Real:     [1.0993, 1.2299] kg/m³
#
#   ✅ Potencia eólica específica corregida por densidad
#      Esperado: [0, 6000] W/m²
#      Real:     [0.0000, 1034.3780] W/m²
#
#   ✅ Precipitación hidráulica ponderada
#      Esperado: [0, 0.15] m
#      Real:     [0.0000, 0.0017] m
#
#   ℹ️  Horas con wind_shear capeado a 5: 6 (0.07%)
#   ✅ Capeado puntual — normal en calmas nocturnas de superficie
#
# ==================================================
# 📊 BLOQUE 5 - VISUALIZACIONES
# ==================================================
#   ✅ Gráfico guardado: 2020/validacion_2020.png
#
# ==================================================
# 📊 BLOQUE 6 - RESUMEN ESTADÍSTICO
# ==================================================
#
# 🌡️  TÉRMICO (pesos INE 2020):
#        hdd_peninsular_ponderado  cdd_peninsular_ponderado  estres_termico_total
# count               8784.000000               8784.000000           8784.000000
# mean                   0.197844                  0.012274              0.210118
# std                    0.179910                  0.037495              0.170170
# min                    0.000000                  0.000000              0.000000
# 25%                    0.025946                  0.000000              0.057104
# 50%                    0.158320                  0.000000              0.172097
# 75%                    0.335064                  0.000000              0.335064
# max                    0.765553                  0.274968              0.765553
#
#   ℹ️  Horas con HDD>0 y CDD>0 simultáneamente: 1,363 (15.5% del año)
#   ✅ Esto es física real - norte frío + sur cálido a la vez
#      El modelo aprende este gradiente térmico peninsular
#
#   📅 Distribución mensual del solapamiento (norte frío + sur cálido simultáneo):
#   Mes     Horas  % del mes Barra visual
#   -------------------------------------------------------
#   Mar        10       1.3%
#   Abr         2       0.3%
#   May       160      21.5%  ██████████
#   Jun       269      37.4%  ██████████████████
#   Jul       354      47.6%  ███████████████████████
#   Ago       313      42.1%  █████████████████████
#   Sep       188      26.1%  █████████████
#   Oct        66       8.9%  ████
#   Nov         1       0.1%
#
#   🔝 Mes con más solapamiento:   Jul (354h) ← transición térmica máxima
#   🔽 Mes con menos solapamiento: Nov (1h) ← clima más homogéneo
#
#   📊 Verificación hipótesis climática:
#      Meses de transición (Mar-May, Sep-Nov): 427h (31.3%)
#      Meses extremos (Ene-Feb, Jun-Ago, Dic): 936h (68.7%)
#      ℹ️  El solapamiento se distribuye de forma atípica - año 2020 inusual
#
#   🕐 Hora del día con más solapamiento: 19:00h (105 ocurrencias)
#      Noche (18-24h) - cuando el gradiente N/S es más pronunciado
#
# ⚡ ENERGÉTICO:
#        ssrd_solar_ponderado  tcc_solar_ponderado  t2m_celsius_solar_ponderado  wind_speed_100m_ponderado  wind_speed_10m_ponderado  wind_shear_ponderado  tp_hidro_ponderado
# count          8.784000e+03            8784.0000                    8784.0000                  8784.0000                 8784.0000             8784.0000           8784.0000
# mean           7.277885e+05               0.4405                      16.1913                     3.3502                    2.2434                1.5176              0.0001
# std            9.880020e+05               0.2859                       7.0293                     2.1025                    1.4336                0.2612              0.0001
# min            0.000000e+00               0.0010                       0.5255                     0.0257                    0.0363                0.1710              0.0000
# 25%            0.000000e+00               0.1775                      10.8272                     1.7906                    1.1804                1.3492              0.0000
# 50%            4.445189e+04               0.4314                      15.0952                     2.9394                    1.9636                1.4979              0.0000
# 75%            1.376952e+06               0.6878                      21.1168                     4.4632                    2.9660                1.6337              0.0001
# max            3.513152e+06               0.9978                      34.8787                    12.0941                    8.7364                5.0000              0.0017
#
# ============================================================
#
# ✅ Validación 2020 completada
# ============================================================
#
# ============================================================
# Validación año 2021
# ============================================================
# ✅ Dataset cargado - Shape: (8760, 13)
#
# ==================================================
# 📋 BLOQUE 1 - ESTRUCTURA
# ==================================================
#
# 🔢 Filas:    8,760
# 🔢 Columnas: 13
#
# 📌 Columnas presentes:
# ['time', 'tcc_solar_ponderado', 'hdd_peninsular_ponderado', 'cdd_peninsular_ponderado', 'estres_termico_total', 'ssrd_solar_ponderado', 'tp_hidro_ponderado', 'wind_speed_100m_ponderado', 'wind_speed_10m_ponderado', 'wind_shear_ponderado', 'densidad_aire_eolica', 'wind_power_density_ponderado', 't2m_celsius_solar_ponderado']
#
# 📌 Tipos de datos:
# time                            datetime64[us]
# tcc_solar_ponderado                    float64
# hdd_peninsular_ponderado               float64
# cdd_peninsular_ponderado               float64
# estres_termico_total                   float64
# ssrd_solar_ponderado                   float64
# tp_hidro_ponderado                     float64
# wind_speed_100m_ponderado              float64
# wind_speed_10m_ponderado               float64
# wind_shear_ponderado                   float64
# densidad_aire_eolica                   float64
# wind_power_density_ponderado           float64
# t2m_celsius_solar_ponderado            float64
# dtype: object
#
# ✅ Todas las columnas esperadas presentes
#
# ==================================================
# 🕐 BLOQUE 2 - COBERTURA TEMPORAL
# ==================================================
#
# 📅 Inicio:  2021-01-01 00:00:00
# 📅 Fin:     2021-12-31 23:00:00
# 📅 Horas:   8,760 / 8,760 esperadas
# ✅ Cobertura temporal completa
# ✅ Serie temporal continua, sin saltos
#
# ==================================================
# 🔍 BLOQUE 3 - NULOS Y DUPLICADOS
# ==================================================
#
# ✅ Sin valores nulos
#
# ✅ Filas duplicadas por time: 0
#
# ==================================================
# 🌡️  BLOQUE 4 - RANGOS FÍSICOS
# ==================================================
#
#   ⚠️  HDD peninsular ponderado
#      Esperado: [0, 0.7916666666666666] °día/h
#      Real:     [0.0000, 0.8372] °día/h
#
#   ✅ CDD peninsular ponderado
#      Esperado: [0, 1.125] °día/h
#      Real:     [0.0000, 0.3350] °día/h
#
#   ✅ Estrés térmico total
#      Esperado: [0, 1.9166666666666667] °día/h
#      Real:     [0.0000, 0.8372] °día/h
#
#   ✅ Radiación solar ponderada
#      Esperado: [0, 4000000.0] J/m²
#      Real:     [0.0000, 3522364.5000] J/m²
#
#   ✅ Nubosidad ponderada
#      Esperado: [0, 1] -
#      Real:     [0.0004, 0.9996] -
#
#   ✅ Temperatura solar ponderada
#      Esperado: [-15, 48] °C
#      Real:     [-2.0782, 37.6228] °C
#
#   ✅ Viento 100m ponderado
#      Esperado: [0, 60] m/s
#      Real:     [0.0294, 11.5906] m/s
#
#   ✅ Viento 10m ponderado
#      Esperado: [0, 40] m/s
#      Real:     [0.0358, 7.7218] m/s
#
#   ✅ Wind shear ponderado
#      Esperado: [0, 5] -
#      Real:     [0.1260, 5.0000] -
#
#   ✅ Densidad del aire en zonas eólicas peninsulares
#      Esperado: [1.05, 1.4] kg/m³
#      Real:     [1.1028, 1.2375] kg/m³
#
#   ✅ Potencia eólica específica corregida por densidad
#      Esperado: [0, 6000] W/m²
#      Real:     [0.0000, 908.2499] W/m²
#
#   ✅ Precipitación hidráulica ponderada
#      Esperado: [0, 0.15] m
#      Real:     [0.0000, 0.0015] m
#
#   ℹ️  Horas con wind_shear capeado a 5: 2 (0.02%)
#   ✅ Capeado puntual — normal en calmas nocturnas de superficie
#
# ==================================================
# 📊 BLOQUE 5 - VISUALIZACIONES
# ==================================================
#   ✅ Gráfico guardado: 2021/validacion_2021.png
#
# ==================================================
# 📊 BLOQUE 6 - RESUMEN ESTADÍSTICO
# ==================================================
#
# 🌡️  TÉRMICO (pesos INE 2021):
#        hdd_peninsular_ponderado  cdd_peninsular_ponderado  estres_termico_total
# count               8760.000000               8760.000000           8760.000000
# mean                   0.208874                  0.009907              0.218781
# std                    0.190374                  0.032715              0.182293
# min                    0.000000                  0.000000              0.000000
# 25%                    0.030055                  0.000000              0.055226
# 50%                    0.163115                  0.000000              0.170204
# 75%                    0.352078                  0.000000              0.352078
# max                    0.837174                  0.335035              0.837174
#
#   ℹ️  Horas con HDD>0 y CDD>0 simultáneamente: 1,574 (18.0% del año)
#   ✅ Esto es física real - norte frío + sur cálido a la vez
#      El modelo aprende este gradiente térmico peninsular
#
#   📅 Distribución mensual del solapamiento (norte frío + sur cálido simultáneo):
#   Mes     Horas  % del mes Barra visual
#   -------------------------------------------------------
#   Mar         6       0.8%
#   Abr         3       0.4%
#   May       197      26.5%  █████████████
#   Jun       286      39.7%  ███████████████████
#   Jul       421      56.6%  ████████████████████████████
#   Ago       330      44.4%  ██████████████████████
#   Sep       218      30.3%  ███████████████
#   Oct       113      15.2%  ███████
#
#   🔝 Mes con más solapamiento:   Jul (421h) ← transición térmica máxima
#   🔽 Mes con menos solapamiento: Abr (3h) ← clima más homogéneo
#
#   📊 Verificación hipótesis climática:
#      Meses de transición (Mar-May, Sep-Nov): 537h (34.1%)
#      Meses extremos (Ene-Feb, Jun-Ago, Dic): 1,037h (65.9%)
#      ℹ️  El solapamiento se distribuye de forma atípica - año 2021 inusual
#
#   🕐 Hora del día con más solapamiento: 17:00h (126 ocurrencias)
#      Tarde (12-18h) - cuando el gradiente N/S es más pronunciado
#
# ⚡ ENERGÉTICO:
#        ssrd_solar_ponderado  tcc_solar_ponderado  t2m_celsius_solar_ponderado  wind_speed_100m_ponderado  wind_speed_10m_ponderado  wind_shear_ponderado  tp_hidro_ponderado
# count          8.760000e+03            8760.0000                    8760.0000                  8760.0000                 8760.0000             8760.0000           8760.0000
# mean           7.341421e+05               0.4424                      15.7581                     3.3333                    2.2400                1.4962              0.0001
# std            9.968171e+05               0.2773                       7.1888                     1.9804                    1.3233                0.2307              0.0001
# min            0.000000e+00               0.0004                      -2.0782                     0.0294                    0.0358                0.1260              0.0000
# 25%            0.000000e+00               0.2015                      10.3191                     1.8780                    1.2699                1.3389              0.0000
# 50%            4.708593e+04               0.4034                      15.1042                     2.9949                    2.0078                1.4932              0.0000
# 75%            1.372176e+06               0.6793                      20.8210                     4.3572                    2.9027                1.6086              0.0001
# max            3.522364e+06               0.9996                      37.6228                    11.5906                    7.7218                5.0000              0.0015
#
# ============================================================
#
# ✅ Validación 2021 completada
# ============================================================
#
# ============================================================
# Validación año 2022
# ============================================================
# ✅ Dataset cargado - Shape: (8760, 13)
#
# ==================================================
# 📋 BLOQUE 1 - ESTRUCTURA
# ==================================================
#
# 🔢 Filas:    8,760
# 🔢 Columnas: 13
#
# 📌 Columnas presentes:
# ['time', 'tcc_solar_ponderado', 'hdd_peninsular_ponderado', 'cdd_peninsular_ponderado', 'estres_termico_total', 'ssrd_solar_ponderado', 'tp_hidro_ponderado', 'wind_speed_100m_ponderado', 'wind_speed_10m_ponderado', 'wind_shear_ponderado', 'densidad_aire_eolica', 'wind_power_density_ponderado', 't2m_celsius_solar_ponderado']
#
# 📌 Tipos de datos:
# time                            datetime64[us]
# tcc_solar_ponderado                    float64
# hdd_peninsular_ponderado               float64
# cdd_peninsular_ponderado               float64
# estres_termico_total                   float64
# ssrd_solar_ponderado                   float64
# tp_hidro_ponderado                     float64
# wind_speed_100m_ponderado              float64
# wind_speed_10m_ponderado               float64
# wind_shear_ponderado                   float64
# densidad_aire_eolica                   float64
# wind_power_density_ponderado           float64
# t2m_celsius_solar_ponderado            float64
# dtype: object
#
# ✅ Todas las columnas esperadas presentes
#
# ==================================================
# 🕐 BLOQUE 2 - COBERTURA TEMPORAL
# ==================================================
#
# 📅 Inicio:  2022-01-01 00:00:00
# 📅 Fin:     2022-12-31 23:00:00
# 📅 Horas:   8,760 / 8,760 esperadas
# ✅ Cobertura temporal completa
# ✅ Serie temporal continua, sin saltos
#
# ==================================================
# 🔍 BLOQUE 3 - NULOS Y DUPLICADOS
# ==================================================
#
# ✅ Sin valores nulos
#
# ✅ Filas duplicadas por time: 0
#
# ==================================================
# 🌡️  BLOQUE 4 - RANGOS FÍSICOS
# ==================================================
#
#   ✅ HDD peninsular ponderado
#      Esperado: [0, 0.7916666666666666] °día/h
#      Real:     [0.0000, 0.7547] °día/h
#
#   ✅ CDD peninsular ponderado
#      Esperado: [0, 1.125] °día/h
#      Real:     [0.0000, 0.3266] °día/h
#
#   ✅ Estrés térmico total
#      Esperado: [0, 1.9166666666666667] °día/h
#      Real:     [0.0000, 0.7547] °día/h
#
#   ✅ Radiación solar ponderada
#      Esperado: [0, 4000000.0] J/m²
#      Real:     [0.0000, 3564447.2000] J/m²
#
#   ✅ Nubosidad ponderada
#      Esperado: [0, 1] -
#      Real:     [0.0001, 0.9997] -
#
#   ✅ Temperatura solar ponderada
#      Esperado: [-15, 48] °C
#      Real:     [1.0773, 37.1387] °C
#
#   ✅ Viento 100m ponderado
#      Esperado: [0, 60] m/s
#      Real:     [0.0397, 10.3857] m/s
#
#   ✅ Viento 10m ponderado
#      Esperado: [0, 40] m/s
#      Real:     [0.0211, 6.9936] m/s
#
#   ✅ Wind shear ponderado
#      Esperado: [0, 5] -
#      Real:     [0.3539, 5.0000] -
#
#   ✅ Densidad del aire en zonas eólicas peninsulares
#      Esperado: [1.05, 1.4] kg/m³
#      Real:     [1.0960, 1.2331] kg/m³
#
#   ✅ Potencia eólica específica corregida por densidad
#      Esperado: [0, 6000] W/m²
#      Real:     [0.0000, 655.7889] W/m²
#
#   ✅ Precipitación hidráulica ponderada
#      Esperado: [0, 0.15] m
#      Real:     [0.0000, 0.0014] m
#
#   ℹ️  Horas con wind_shear capeado a 5: 2 (0.02%)
#   ✅ Capeado puntual — normal en calmas nocturnas de superficie
#
# ==================================================
# 📊 BLOQUE 5 - VISUALIZACIONES
# ==================================================
#   ✅ Gráfico guardado: 2022/validacion_2022.png
#
# ==================================================
# 📊 BLOQUE 6 - RESUMEN ESTADÍSTICO
# ==================================================
#
# 🌡️  TÉRMICO (pesos INE 2022):
#        hdd_peninsular_ponderado  cdd_peninsular_ponderado  estres_termico_total
# count               8760.000000               8760.000000           8760.000000
# mean                   0.187411                  0.016901              0.204313
# std                    0.186143                  0.048235              0.175167
# min                    0.000000                  0.000000              0.000027
# 25%                    0.014034                  0.000000              0.045491
# 50%                    0.130609                  0.000000              0.159945
# 75%                    0.328062                  0.000720              0.328062
# max                    0.754688                  0.326551              0.754688
#
#   ℹ️  Horas con HDD>0 y CDD>0 simultáneamente: 1,680 (19.2% del año)
#   ✅ Esto es física real - norte frío + sur cálido a la vez
#      El modelo aprende este gradiente térmico peninsular
#
#   📅 Distribución mensual del solapamiento (norte frío + sur cálido simultáneo):
#   Mes     Horas  % del mes Barra visual
#   -------------------------------------------------------
#   Abr        19       2.6%  █
#   May       282      37.9%  ██████████████████
#   Jun       358      49.7%  ████████████████████████
#   Jul       316      42.5%  █████████████████████
#   Ago       341      45.8%  ██████████████████████
#   Sep       222      30.8%  ███████████████
#   Oct       142      19.1%  █████████
#
#   🔝 Mes con más solapamiento:   Jun (358h) ← transición térmica máxima
#   🔽 Mes con menos solapamiento: Abr (19h) ← clima más homogéneo
#
#   📊 Verificación hipótesis climática:
#      Meses de transición (Mar-May, Sep-Nov): 665h (39.6%)
#      Meses extremos (Ene-Feb, Jun-Ago, Dic): 1,015h (60.4%)
#      ℹ️  El solapamiento se distribuye de forma atípica - año 2022 inusual
#
#   🕐 Hora del día con más solapamiento: 18:00h (113 ocurrencias)
#      Noche (18-24h) - cuando el gradiente N/S es más pronunciado
#
# ⚡ ENERGÉTICO:
#        ssrd_solar_ponderado  tcc_solar_ponderado  t2m_celsius_solar_ponderado  wind_speed_100m_ponderado  wind_speed_10m_ponderado  wind_shear_ponderado  tp_hidro_ponderado
# count          8.760000e+03            8760.0000                    8760.0000                  8760.0000                 8760.0000             8760.0000           8760.0000
# mean           7.342722e+05               0.4465                      16.7925                     3.1883                    2.1223                1.5199              0.0001
# std            1.003148e+06               0.2933                       7.6454                     1.7845                    1.1923                0.2418              0.0001
# min            0.000000e+00               0.0001                       1.0773                     0.0397                    0.0211                0.3539              0.0000
# 25%            0.000000e+00               0.1838                      10.8013                     1.8385                    1.2251                1.3572              0.0000
# 50%            4.638401e+04               0.4065                      15.7642                     2.8541                    1.8978                1.4980              0.0000
# 75%            1.368857e+06               0.7047                      22.4607                     4.2556                    2.8610                1.6330              0.0001
# max            3.564447e+06               0.9997                      37.1387                    10.3857                    6.9936                5.0000              0.0014
#
# ============================================================
#
# ✅ Validación 2022 completada
# ============================================================
#
# ============================================================
# Validación año 2023
# ============================================================
# ✅ Dataset cargado - Shape: (8760, 13)
#
# ==================================================
# 📋 BLOQUE 1 - ESTRUCTURA
# ==================================================
#
# 🔢 Filas:    8,760
# 🔢 Columnas: 13
#
# 📌 Columnas presentes:
# ['time', 'tcc_solar_ponderado', 'hdd_peninsular_ponderado', 'cdd_peninsular_ponderado', 'estres_termico_total', 'ssrd_solar_ponderado', 'tp_hidro_ponderado', 'wind_speed_100m_ponderado', 'wind_speed_10m_ponderado', 'wind_shear_ponderado', 'densidad_aire_eolica', 'wind_power_density_ponderado', 't2m_celsius_solar_ponderado']
#
# 📌 Tipos de datos:
# time                            datetime64[us]
# tcc_solar_ponderado                    float64
# hdd_peninsular_ponderado               float64
# cdd_peninsular_ponderado               float64
# estres_termico_total                   float64
# ssrd_solar_ponderado                   float64
# tp_hidro_ponderado                     float64
# wind_speed_100m_ponderado              float64
# wind_speed_10m_ponderado               float64
# wind_shear_ponderado                   float64
# densidad_aire_eolica                   float64
# wind_power_density_ponderado           float64
# t2m_celsius_solar_ponderado            float64
# dtype: object
#
# ✅ Todas las columnas esperadas presentes
#
# ==================================================
# 🕐 BLOQUE 2 - COBERTURA TEMPORAL
# ==================================================
#
# 📅 Inicio:  2023-01-01 00:00:00
# 📅 Fin:     2023-12-31 23:00:00
# 📅 Horas:   8,760 / 8,760 esperadas
# ✅ Cobertura temporal completa
# ✅ Serie temporal continua, sin saltos
#
# ==================================================
# 🔍 BLOQUE 3 - NULOS Y DUPLICADOS
# ==================================================
#
# ✅ Sin valores nulos
#
# ✅ Filas duplicadas por time: 0
#
# ==================================================
# 🌡️  BLOQUE 4 - RANGOS FÍSICOS
# ==================================================
#
#   ✅ HDD peninsular ponderado
#      Esperado: [0, 0.7916666666666666] °día/h
#      Real:     [0.0000, 0.7724] °día/h
#
#   ✅ CDD peninsular ponderado
#      Esperado: [0, 1.125] °día/h
#      Real:     [0.0000, 0.3612] °día/h
#
#   ✅ Estrés térmico total
#      Esperado: [0, 1.9166666666666667] °día/h
#      Real:     [0.0000, 0.7724] °día/h
#
#   ✅ Radiación solar ponderada
#      Esperado: [0, 4000000.0] J/m²
#      Real:     [0.0000, 3495544.0000] J/m²
#
#   ✅ Nubosidad ponderada
#      Esperado: [0, 1] -
#      Real:     [0.0001, 0.9998] -
#
#   ✅ Temperatura solar ponderada
#      Esperado: [-15, 48] °C
#      Real:     [-0.6649, 36.5233] °C
#
#   ✅ Viento 100m ponderado
#      Esperado: [0, 60] m/s
#      Real:     [0.0165, 12.2585] m/s
#
#   ✅ Viento 10m ponderado
#      Esperado: [0, 40] m/s
#      Real:     [0.0206, 8.7992] m/s
#
#   ✅ Wind shear ponderado
#      Esperado: [0, 5] -
#      Real:     [0.1301, 5.0000] -
#
#   ✅ Densidad del aire en zonas eólicas peninsulares
#      Esperado: [1.05, 1.4] kg/m³
#      Real:     [1.0906, 1.2373] kg/m³
#
#   ✅ Potencia eólica específica corregida por densidad
#      Esperado: [0, 6000] W/m²
#      Real:     [0.0000, 1076.0895] W/m²
#
#   ✅ Precipitación hidráulica ponderada
#      Esperado: [0, 0.15] m
#      Real:     [0.0000, 0.0021] m
#
#   ℹ️  Horas con wind_shear capeado a 5: 4 (0.05%)
#   ✅ Capeado puntual — normal en calmas nocturnas de superficie
#
# ==================================================
# 📊 BLOQUE 5 - VISUALIZACIONES
# ==================================================
#   ✅ Gráfico guardado: 2023/validacion_2023.png
#
# ==================================================
# 📊 BLOQUE 6 - RESUMEN ESTADÍSTICO
# ==================================================
#
# 🌡️  TÉRMICO (pesos INE 2023):
#        hdd_peninsular_ponderado  cdd_peninsular_ponderado  estres_termico_total
# count               8760.000000               8760.000000           8760.000000
# mean                   0.188756                  0.014829              0.203585
# std                    0.197945                  0.044933              0.188799
# min                    0.000000                  0.000000              0.000000
# 25%                    0.016000                  0.000000              0.041669
# 50%                    0.110929                  0.000000              0.141270
# 75%                    0.324663                  0.000499              0.325263
# max                    0.772354                  0.361177              0.772354
#
#   ℹ️  Horas con HDD>0 y CDD>0 simultáneamente: 1,618 (18.5% del año)
#   ✅ Esto es física real - norte frío + sur cálido a la vez
#      El modelo aprende este gradiente térmico peninsular
#
#   📅 Distribución mensual del solapamiento (norte frío + sur cálido simultáneo):
#   Mes     Horas  % del mes Barra visual
#   -------------------------------------------------------
#   Mar        61       8.2%  ████
#   Abr       169      23.5%  ███████████
#   May       174      23.4%  ███████████
#   Jun       259      36.0%  █████████████████
#   Jul       393      52.8%  ██████████████████████████
#   Ago       345      46.4%  ███████████████████████
#   Sep       141      19.6%  █████████
#   Oct        66       8.9%  ████
#   Nov         9       1.2%
#   Dic         1       0.1%
#
#   🔝 Mes con más solapamiento:   Jul (393h) ← transición térmica máxima
#   🔽 Mes con menos solapamiento: Dic (1h) ← clima más homogéneo
#
#   📊 Verificación hipótesis climática:
#      Meses de transición (Mar-May, Sep-Nov): 620h (38.3%)
#      Meses extremos (Ene-Feb, Jun-Ago, Dic): 998h (61.7%)
#      ℹ️  El solapamiento se distribuye de forma atípica - año 2023 inusual
#
#   🕐 Hora del día con más solapamiento: 14:00h (118 ocurrencias)
#      Tarde (12-18h) - cuando el gradiente N/S es más pronunciado
#
# ⚡ ENERGÉTICO:
#        ssrd_solar_ponderado  tcc_solar_ponderado  t2m_celsius_solar_ponderado  wind_speed_100m_ponderado  wind_speed_10m_ponderado  wind_shear_ponderado  tp_hidro_ponderado
# count          8.760000e+03            8760.0000                    8760.0000                  8760.0000                 8760.0000             8760.0000           8760.0000
# mean           7.520153e+05               0.4096                      16.5245                     3.3266                    2.2299                1.5048              0.0001
# std            1.016168e+06               0.2859                       7.8059                     2.1654                    1.4654                0.2294              0.0002
# min            0.000000e+00               0.0001                      -0.6649                     0.0165                    0.0206                0.1301              0.0000
# 25%            0.000000e+00               0.1468                      10.7193                     1.6629                    1.1156                1.3497              0.0000
# 50%            4.687322e+04               0.3689                      16.2792                     2.8373                    1.8923                1.5013              0.0000
# 75%            1.406010e+06               0.6534                      21.9438                     4.5793                    3.0747                1.6221              0.0001
# max            3.495544e+06               0.9998                      36.5233                    12.2585                    8.7992                5.0000              0.0021
#
# ============================================================
#
# ✅ Validación 2023 completada
# ============================================================
#
# ============================================================
# Validación año 2024
# ============================================================
# ✅ Dataset cargado - Shape: (8784, 13)
#
# ==================================================
# 📋 BLOQUE 1 - ESTRUCTURA
# ==================================================
#
# 🔢 Filas:    8,784
# 🔢 Columnas: 13
#
# 📌 Columnas presentes:
# ['time', 'tcc_solar_ponderado', 'hdd_peninsular_ponderado', 'cdd_peninsular_ponderado', 'estres_termico_total', 'ssrd_solar_ponderado', 'tp_hidro_ponderado', 'wind_speed_100m_ponderado', 'wind_speed_10m_ponderado', 'wind_shear_ponderado', 'densidad_aire_eolica', 'wind_power_density_ponderado', 't2m_celsius_solar_ponderado']
#
# 📌 Tipos de datos:
# time                            datetime64[us]
# tcc_solar_ponderado                    float64
# hdd_peninsular_ponderado               float64
# cdd_peninsular_ponderado               float64
# estres_termico_total                   float64
# ssrd_solar_ponderado                   float64
# tp_hidro_ponderado                     float64
# wind_speed_100m_ponderado              float64
# wind_speed_10m_ponderado               float64
# wind_shear_ponderado                   float64
# densidad_aire_eolica                   float64
# wind_power_density_ponderado           float64
# t2m_celsius_solar_ponderado            float64
# dtype: object
#
# ✅ Todas las columnas esperadas presentes
#
# ==================================================
# 🕐 BLOQUE 2 - COBERTURA TEMPORAL
# ==================================================
#
# 📅 Inicio:  2024-01-01 00:00:00
# 📅 Fin:     2024-12-31 23:00:00
# 📅 Horas:   8,784 / 8,784 esperadas
# ✅ Cobertura temporal completa
# ✅ Serie temporal continua, sin saltos
#
# ==================================================
# 🔍 BLOQUE 3 - NULOS Y DUPLICADOS
# ==================================================
#
# ✅ Sin valores nulos
#
# ✅ Filas duplicadas por time: 0
#
# ==================================================
# 🌡️  BLOQUE 4 - RANGOS FÍSICOS
# ==================================================
#
#   ✅ HDD peninsular ponderado
#      Esperado: [0, 0.7916666666666666] °día/h
#      Real:     [0.0000, 0.6997] °día/h
#
#   ✅ CDD peninsular ponderado
#      Esperado: [0, 1.125] °día/h
#      Real:     [0.0000, 0.2991] °día/h
#
#   ✅ Estrés térmico total
#      Esperado: [0, 1.9166666666666667] °día/h
#      Real:     [0.0000, 0.6997] °día/h
#
#   ✅ Radiación solar ponderada
#      Esperado: [0, 4000000.0] J/m²
#      Real:     [0.0000, 3534700.2000] J/m²
#
#   ✅ Nubosidad ponderada
#      Esperado: [0, 1] -
#      Real:     [0.0000, 1.0000] -
#
#   ✅ Temperatura solar ponderada
#      Esperado: [-15, 48] °C
#      Real:     [1.7661, 36.4110] °C
#
#   ✅ Viento 100m ponderado
#      Esperado: [0, 60] m/s
#      Real:     [0.0093, 11.2597] m/s
#
#   ✅ Viento 10m ponderado
#      Esperado: [0, 40] m/s
#      Real:     [0.0166, 7.8728] m/s
#
#   ✅ Wind shear ponderado
#      Esperado: [0, 5] -
#      Real:     [0.0763, 5.0000] -
#
#   ✅ Densidad del aire en zonas eólicas peninsulares
#      Esperado: [1.05, 1.4] kg/m³
#      Real:     [1.0960, 1.2300] kg/m³
#
#   ✅ Potencia eólica específica corregida por densidad
#      Esperado: [0, 6000] W/m²
#      Real:     [0.0000, 824.5417] W/m²
#
#   ✅ Precipitación hidráulica ponderada
#      Esperado: [0, 0.15] m
#      Real:     [0.0000, 0.0011] m
#
#   ℹ️  Horas con wind_shear capeado a 5: 8 (0.09%)
#   ✅ Capeado puntual — normal en calmas nocturnas de superficie
#
# ==================================================
# 📊 BLOQUE 5 - VISUALIZACIONES
# ==================================================
#   ✅ Gráfico guardado: 2024/validacion_2024.png
#
# ==================================================
# 📊 BLOQUE 6 - RESUMEN ESTADÍSTICO
# ==================================================
#
# 🌡️  TÉRMICO (pesos INE 2024):
#        hdd_peninsular_ponderado  cdd_peninsular_ponderado  estres_termico_total
# count               8784.000000               8784.000000           8784.000000
# mean                   0.183302                  0.012646              0.195948
# std                    0.172315                  0.040144              0.163460
# min                    0.000000                  0.000000              0.000006
# 25%                    0.023383                  0.000000              0.049844
# 50%                    0.137689                  0.000000              0.155529
# 75%                    0.312064                  0.000000              0.312064
# max                    0.699674                  0.299084              0.699674
#
#   ℹ️  Horas con HDD>0 y CDD>0 simultáneamente: 1,580 (18.0% del año)
#   ✅ Esto es física real - norte frío + sur cálido a la vez
#      El modelo aprende este gradiente térmico peninsular
#
#   📅 Distribución mensual del solapamiento (norte frío + sur cálido simultáneo):
#   Mes     Horas  % del mes Barra visual
#   -------------------------------------------------------
#   Mar        15       2.0%  █
#   Abr        72      10.0%  █████
#   May       187      25.1%  ████████████
#   Jun       333      46.2%  ███████████████████████
#   Jul       311      41.8%  ████████████████████
#   Ago       334      44.9%  ██████████████████████
#   Sep       243      33.8%  ████████████████
#   Oct        85      11.4%  █████
#
#   🔝 Mes con más solapamiento:   Ago (334h) ← transición térmica máxima
#   🔽 Mes con menos solapamiento: Mar (15h) ← clima más homogéneo
#
#   📊 Verificación hipótesis climática:
#      Meses de transición (Mar-May, Sep-Nov): 602h (38.1%)
#      Meses extremos (Ene-Feb, Jun-Ago, Dic): 978h (61.9%)
#      ℹ️  El solapamiento se distribuye de forma atípica - año 2024 inusual
#
#   🕐 Hora del día con más solapamiento: 16:00h (120 ocurrencias)
#      Tarde (12-18h) - cuando el gradiente N/S es más pronunciado
#
# ⚡ ENERGÉTICO:
#        ssrd_solar_ponderado  tcc_solar_ponderado  t2m_celsius_solar_ponderado  wind_speed_100m_ponderado  wind_speed_10m_ponderado  wind_shear_ponderado  tp_hidro_ponderado
# count          8.784000e+03            8784.0000                    8784.0000                  8784.0000                 8784.0000             8784.0000           8784.0000
# mean           7.310185e+05               0.4382                      16.4000                     3.3650                    2.2479                1.5196              0.0001
# std            9.959586e+05               0.2817                       7.0832                     2.0425                    1.3772                0.2634              0.0001
# min            0.000000e+00               0.0000                       1.7661                     0.0093                    0.0166                0.0763              0.0000
# 25%            0.000000e+00               0.1907                      10.9627                     1.9461                    1.3005                1.3545              0.0000
# 50%            4.510935e+04               0.4122                      15.6534                     2.9550                    1.9611                1.5027              0.0000
# 75%            1.354493e+06               0.6731                      21.1797                     4.2469                    2.8366                1.6269              0.0001
# max            3.534700e+06               1.0000                      36.4110                    11.2597                    7.8728                5.0000              0.0011
#
# ============================================================
#
# ✅ Validación 2024 completada
# ============================================================

# %%
import os
import glob

# 1. Borrar todos los índices corruptos
idx_files = glob.glob('2025/*.idx')
for f in idx_files:
    os.remove(f)
    print(f"🗑️ Borrado: {f}")

# 2. Ahora inspeccionar
import xarray as xr
import warnings
warnings.filterwarnings('ignore')

# Cargar accum SIN ningún filtro para ver su estructura real
ds_raw = xr.open_dataset(
    '2025/data2025DatosClima.grib',
    engine='cfgrib',
    backend_kwargs={'filter_by_keys': {'stepType': 'accum'}}
)

print("=== ESTRUCTURA RAW ACCUM ===")
print(ds_raw)
print("\n=== DIMENSIONES ===")
print(ds_raw.dims)
print("\n=== COORDENADAS ===")
for coord in ds_raw.coords:
    try:
        vals = ds_raw[coord].values
        print(f"\n{coord}: shape={vals.shape}")
        if vals.size <= 30:
            print(f"  valores: {vals}")
        else:
            print(f"  primeros: {vals.flat[:5]}")
            print(f"  últimos:  {vals.flat[-5:]}")
    except:
        print(f"{coord}: no se puede mostrar")
# Out:
# 🗑️ Borrado: 2025\data2025DatosClima.grib.5b7b6.idx
# === ESTRUCTURA RAW ACCUM ===
# <xarray.Dataset> Size: 141MB
# Dimensions:     (time: 731, step: 12, latitude: 33, longitude: 61)
# Coordinates:
#   * time        (time) datetime64[ns] 6kB 2024-12-31T18:00:00 ... 2025-12-31T...
#   * step        (step) timedelta64[ns] 96B 01:00:00 02:00:00 ... 12:00:00
#     valid_time  (time, step) datetime64[ns] 70kB ...
#   * latitude    (latitude) float64 264B 44.0 43.75 43.5 ... 36.5 36.25 36.0
#   * longitude   (longitude) float64 488B -10.0 -9.75 -9.5 -9.25 ... 4.5 4.75 5.0
#     number      int64 8B ...
#     surface     float64 8B ...
# Data variables:
#     tp          (time, step, latitude, longitude) float32 71MB ...
#     ssrd        (time, step, latitude, longitude) float32 71MB ...
# Attributes:
#     GRIB_edition:            1
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-04-12T17:58 GRIB to CDM+CF via cfgrib-0.9.1...
#
# === DIMENSIONES ===
# FrozenMappingWarningOnValuesAccess({'time': 731, 'step': 12, 'latitude': 33, 'longitude': 61})
#
# === COORDENADAS ===
#
# number: shape=()
#   valores: 0
#
# time: shape=(731,)
#   primeros: ['2024-12-31T18:00:00.000000000' '2025-01-01T06:00:00.000000000'
#  '2025-01-01T18:00:00.000000000' '2025-01-02T06:00:00.000000000'
#  '2025-01-02T18:00:00.000000000']
#   últimos:  ['2025-12-29T18:00:00.000000000' '2025-12-30T06:00:00.000000000'
#  '2025-12-30T18:00:00.000000000' '2025-12-31T06:00:00.000000000'
#  '2025-12-31T18:00:00.000000000']
#
# step: shape=(12,)
#   valores: [ 3600000000000  7200000000000 10800000000000 14400000000000
#  18000000000000 21600000000000 25200000000000 28800000000000
#  32400000000000 36000000000000 39600000000000 43200000000000]
#
# surface: shape=()
#   valores: 0.0
#
# latitude: shape=(33,)
#   primeros: [44.   43.75 43.5  43.25 43.  ]
#   últimos:  [37.   36.75 36.5  36.25 36.  ]
#
# longitude: shape=(61,)
#   primeros: [-10.    -9.75  -9.5   -9.25  -9.  ]
#   últimos:  [4.   4.25 4.5  4.75 5.  ]
#
# valid_time: shape=(731, 12)
#   primeros: ['2024-12-31T19:00:00.000000000' '2024-12-31T20:00:00.000000000'
#  '2024-12-31T21:00:00.000000000' '2024-12-31T22:00:00.000000000'
#  '2024-12-31T23:00:00.000000000']
#   últimos:  ['2026-01-01T02:00:00.000000000' '2026-01-01T03:00:00.000000000'
#  '2026-01-01T04:00:00.000000000' '2026-01-01T05:00:00.000000000'
#  '2026-01-01T06:00:00.000000000']
